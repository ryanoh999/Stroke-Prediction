# %% [markdown]
# # Data Collection

# %%
import os
import pandas as pd
df= pd.read_csv('Downloads/healthcare-dataset-stroke-data.csv')

# %% [markdown]
# # Data Definition

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# Check value counts for the categorical features:

# %%
df['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
df['hypertension'].value_counts()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
df['heart_disease'].value_counts()
# Out:
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64

# %%
df['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
df['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
df['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
df['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
df['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %% [markdown]
# This dataset has 3 features with a float data type. Let's take a look at their distributions...

# %%
df['age'].describe()
# Out:
# count    5110.000000
# mean       43.226614
# std        22.612647
# min         0.080000
# 25%        25.000000
# 50%        45.000000
# 75%        61.000000
# max        82.000000
# Name: age, dtype: float64

# %%
df['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %%
df['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In the Data Definition step, I determined via the .info() method that there are null values in, and only in, the bmi column. This may give rise to complications in the pre-processing and modeling steps, but a missing bmi value in and of itself does not lower the quality of a row to an extent that would require me to drop the entry.

# %%
df['id'].duplicated().any()
# Out:
# False

# %% [markdown]
# id is the only column where we don't want any duplicates, so this is good.

# %% [markdown]
# The maximum and the minimum values for the bmi column appear to be out of the range of plausibility. It may be useful to filter out some values at the top and bottom ends of the distribution. The NHSN has defined BMIs below 12 or above 60 as outliers.

# %%
bmisorted = df.sort_values(by='bmi')

# %%
bmisorted[:20]
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 1609  38043  Female   1.24             0              0           No
# 3307   3205  Female  79.00             0              0          Yes
# 2187  59993    Male  40.00             0              0          Yes
# 657   20364  Female   4.00             0              0           No
# 922   45893  Female   8.00             0              0           No
# 3319  53924  Female   1.08             0              0           No
# 3968  41500    Male   0.16             0              0           No
# 3619  52859  Female   4.00             0              0           No
# 4694  31113  Female   1.16             0              0           No
# 1701   4789    Male   8.00             0              0           No
# 3321  56410    Male   1.88             0              0           No
# 4927  25391  Female  10.00             0              0           No
# 2175  48435  Female   2.00             0              0           No
# 3942  60926    Male   5.00             0              0           No
# 425    6107  Female   5.00             0              0           No
# 4021   8247    Male   0.16             0              0           No
# 4527  24736  Female   4.00             0              0           No
# 1614  47350  Female   0.08             0              0           No
# 4196  52447  Female   3.00             0              0           No
# 2812  32560  Female   8.00             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 1609       children          Rural             122.04  10.3        Unknown
# 3307  Self-employed          Urban              79.03  11.3        Unknown
# 2187        Private          Rural              60.96  11.5   never smoked
# 657        children          Urban             107.25  12.0        Unknown
# 922        children          Urban             106.51  12.3        Unknown
# 3319       children          Urban             159.39  12.8        Unknown
# 3968       children          Rural              69.79  13.0        Unknown
# 3619       children          Urban              61.54  13.2        Unknown
# 4694       children          Urban              86.00  13.3        Unknown
# 1701       children          Rural              91.54  13.4        Unknown
# 3321       children          Urban              81.42  13.5        Unknown
# 4927       children          Rural              69.84  13.7        Unknown
# 2175       children          Rural             155.14  13.7        Unknown
# 3942       children          Urban              79.89  13.8        Unknown
# 425        children          Urban              77.88  13.8        Unknown
# 4021       children          Urban             109.52  13.9        Unknown
# 4527       children          Urban              94.27  14.0        Unknown
# 1614       children          Urban             139.67  14.1        Unknown
# 4196       children          Rural             131.81  14.1        Unknown
# 2812       children          Rural              87.92  14.1        Unknown
#
#       stroke
# 1609       0
# 3307       0
# 2187       0
# 657        0
# 922        0
# 3319       0
# 3968       0
# 3619       0
# 4694       0
# 1701       0
# 3321       0
# 4927       0
# 2175       0
# 3942       0
# 425        0
# 4021       0
# 4527       0
# 1614       0
# 4196       0
# 2812       0

# %% [markdown]
# Interestingly enough, none of the individuals with a bottom 20 bmi suffered a stroke!

# %%
bmisorted_desc = df.sort_values(by='bmi', ascending=False)

# %%
bmisorted_desc[:20]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 2128  56420    Male  17.0             1              0           No
# 4209  51856    Male  38.0             1              0          Yes
# 928   41097  Female  23.0             1              0           No
# 544     545    Male  42.0             0              0          Yes
# 1559  37759  Female  53.0             0              0          Yes
# 358   66333    Male  52.0             0              0          Yes
# 4188  70670  Female  27.0             0              0          Yes
# 2764  20292  Female  24.0             0              0          Yes
# 3825  72784  Female  52.0             0              0          Yes
# 2840  65895  Female  52.0             0              0          Yes
# 4838   5131  Female  51.0             0              0          Yes
# 270   72911  Female  57.0             1              0          Yes
# 466    1307  Female  61.0             1              0          Yes
# 3588  23047    Male  43.0             0              0          Yes
# 3060  32604    Male  49.0             0              0          Yes
# 4351  63915  Female  39.0             0              0          Yes
# 1898  25405    Male  62.0             0              0          Yes
# 715    3590  Female  28.0             1              0           No
# 1595   2898    Male  46.0             0              0          Yes
# 4475  60675  Female  48.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 2128        Private          Rural              61.67  97.6        Unknown
# 4209        Private          Rural              56.90  92.0   never smoked
# 928         Private          Urban              70.03  78.0         smokes
# 544         Private          Rural             210.48  71.9   never smoked
# 1559        Private          Rural              72.63  66.8        Unknown
# 358   Self-employed          Urban              78.40  64.8   never smoked
# 4188        Private          Rural              57.96  64.4   never smoked
# 2764        Private          Urban              85.55  63.3   never smoked
# 3825        Private          Rural             118.46  61.6         smokes
# 2840        Private          Urban              98.27  61.2        Unknown
# 4838        Private          Urban             107.72  60.9        Unknown
# 270         Private          Rural             129.54  60.9         smokes
# 466         Private          Rural             170.05  60.2         smokes
# 3588        Private          Urban             100.16  59.7   never smoked
# 3060  Self-employed          Rural             215.81  58.1   never smoked
# 4351        Private          Urban              87.39  57.9   never smoked
# 1898       Govt_job          Urban             187.52  57.7   never smoked
# 715         Private          Rural              80.40  57.5   never smoked
# 1595        Private          Urban              87.66  57.3   never smoked
# 4475       Govt_job          Rural             221.08  57.2   never smoked
#
#       stroke
# 2128       0
# 4209       0
# 928        0
# 544        0
# 1559       0
# 358        0
# 4188       0
# 2764       0
# 3825       0
# 2840       0
# 4838       0
# 270        0
# 466        0
# 3588       0
# 3060       0
# 4351       0
# 1898       0
# 715        0
# 1595       0
# 4475       0

# %% [markdown]
# The same can be said for the individuals with a top 20 bmi! None of them suffered a stroke! We should be very skeptical of these entries. I am going to follow the NIH's guidance by removing the entries that have a bmi below 12 and above 60, but it's fair to wonder whether it would be wise to go beyond that.

# %%
df.drop(df[df['bmi'] < 12].index)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5107 rows x 12 columns]

# %%
df.drop(df[df['bmi'] > 60].index)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5097 rows x 12 columns]

# %%
datapath = '../data'
save_file(df, 'df_cleaned.csv', datapath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-131a0742afa2> in <module>
#       1 datapath = '../data'
# ----> 2 save_file(df, 'df_cleaned.csv', datapath)
#
# NameError: name 'save_file' is not defined
